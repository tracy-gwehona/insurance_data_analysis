# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
insurance_data = pd.read_csv('insurance.csv')
insurance_data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
# data exploration
insurance_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
insurance_data.isna().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
insurance_data.duplicated().sum()
# Out:
# 1

# %%
insurance_data_cleaned = insurance_data.copy()
insurance_data_cleaned.drop_duplicates(inplace=True,keep='first')
insurance_data_cleaned
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1337 rows x 7 columns]

# %%
insurance_data_cleaned.describe()
# Out:
#                age          bmi     children       charges
# count  1337.000000  1337.000000  1337.000000   1337.000000
# mean     39.222139    30.663452     1.095737  13279.121487
# std      14.044333     6.100468     1.205571  12110.359656
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.290000     0.000000   4746.344000
# 50%      39.000000    30.400000     1.000000   9386.161300
# 75%      51.000000    34.700000     2.000000  16657.717450
# max      64.000000    53.130000     5.000000  63770.428010

# %%
# encoding columns with dtype 'object'
# insurance_data_cleaned_encoded = insurance_data_cleaned.copy()
# insurance_data_cleaned_encoded['sex'] = insurance_data_cleaned_encoded['sex'].map({'male': 0, 'female': 1})
# insurance_data_cleaned_encoded['smoker'] = insurance_data_cleaned_encoded['smoker'].map({'no': 0, 'yes': 1})
# insurance_data_cleaned_encoded['region'] = insurance_data_cleaned_encoded['region'].astype('category').cat.codes

# %%
# correlations
fig, ax = plt.subplots(figsize = (10, 8))

sns.heatmap(insurance_data_cleaned.corr(), annot=True, cmap='coolwarm')

ax.set_title('Correlation matrix')

plt.tight_layout()

# %%
fig, ax = plt.subplots(figsize = (20, 16))

sns.barplot(x='age', y='charges', data=insurance_data_cleaned)

ax.set_title('Medical cost charges')
ax.set_xlabel('age')
ax.set_ylabel('charges')

plt.tight_layout()

# %%
fig, ax = plt.subplots(figsize = (10, 8))

sns.boxplot(data=insurance_data_cleaned)

ax.set_title('Box Plot for Insurance Data')

plt.tight_layout()

# %%
fig, ax = plt.subplots(figsize = (10, 8))

sns.scatterplot(data = insurance_data_cleaned)

ax.set_title('Scatter Plot for Insurance Data')

plt.tight_layout()
